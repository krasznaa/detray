# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import patches
import json
import detray.draw.grids as draw_grids

# %%
# Opening rectangle grid JSON file and plot it 
with open('/Users/salzburg/Documents/work/projects/detray/grid_rect.json') as json_file: 
    grid = json.load(json_file) 
    fig, ax = plt.subplots(1, 1, figsize=(10,10))
    draw_grids.rect(fig, ax, grid, linecolor='blue, linewidth='0.5')

# %%
# Opening rectangle grid JSON file and plot it 
with open('/Users/salzburg/Documents/work/projects/detray/grid_pol_sect.json') as json_file: 
    grid = json.load(json_file) 
    fig, ax = plt.subplots(1, 1, figsize=(10,10))
    draw_grids.polar(fig, ax, grid, linecolor='blue', linewidth=1., linestyle=':')
